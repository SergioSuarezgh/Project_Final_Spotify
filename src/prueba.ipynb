# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

from selenium.webdriver.chrome.options import Options

from selenium.webdriver.support import expected_conditions as EC  # condiciones esperadas...

from selenium.webdriver import ActionChains as AC   # acciones encadenadas, rollo doble click

from selenium.webdriver.common.keys import Keys  # manejar teclas

import time

import pandas as pd

from webdriver_manager.chrome import ChromeDriverManager

PATH=ChromeDriverManager().install()

import warnings
warnings.filterwarnings('ignore')

opciones=Options()

# quita la bandera de ser robot
opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)

opciones.headless=False   # si True, no aparece la ventana (headless=no visible)

opciones.add_argument('--start-maximized')         # comienza maximizado

#opciones.add_extension('driver/adblock.crx')       # adblocker

opciones.add_argument('user-data-dir=selenium')    # mantiene las coockies

# %%
def direccion(dia):
    
    
    tabla=driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody')
    
    
    time.sleep(2)
    
            
    #for i in range(1,3):
        
    linea=tabla.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]/td[3]')
         
         
        
    boton=linea.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]/td[8]/span/button')

    tabla_int=driver.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]')
        
    filas=tabla.find_elements(By.TAG_NAME, 'tr')

        
    data=[]

    for f in filas:

        elementos=f.find_elements(By.TAG_NAME, 'td') 

        tmp=[]

        for e in elementos:

            tmp.append(e.text)
            
            
        data.append(tmp)
    df=pd.DataFrame(data, columns=['index', 'novedad','titulo','pos_Actual','pos_Anterior','semanas_lista', 'streams','unnamed1','unnamed2'])
    
    df['dia']=dia
    
    df.novedad=df.novedad.apply(lambda x: x.split('\n'))
    df.titulo=df.titulo.apply(lambda x: x.split('\n'))
    
    df['posicion1']=None
    df['novedad1']=None
    df['titulo1']=None
    df['autor1']=None
    
    for i in range(len(df.novedad)):
        df['posicion1'][i]=df.novedad[i][0]
        df['novedad1'][i]=df.novedad[i][1]
        df.titulo1[i]=df.titulo[i][0]
        df.autor1[i]=df.titulo[i][1]
        
    df = df.reindex(columns=['index','posicion1','novedad1','titulo1','autor1','pos_Actual','pos_Anterior','semanas_lista',
                             'streams','unnamed1','unnamed2'])
    
    

    return df

# %%
def conexion(url,dia):
    driver=webdriver.Chrome(PATH)
    driver.get(url)
    
    time.sleep(2)

    boton_login=driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/main/div[2]/div/header/div/div[2]/a[3]/div[1]').click()
    
    time.sleep(2)
    
    input_mail=driver.find_element(By.XPATH,'//*[@id="login-username"]')
    
    input_mail.send_keys('')  # escribe texto

    input_clave=driver.find_element(By.XPATH,'//*[@id="login-password"]')
    
    
    input_clave.send_keys('')
    
    boton_acceso=driver.find_element(By.XPATH,'//*[@id="login-button"]/div[1]/p').click()
    
    
    driver.get('https://charts.spotify.com/charts/view/regional-global-daily/2017-01-01')
        
    time.sleep(2)
        
    tabla=driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody')
    
    
    time.sleep(2)
    
            
        #for i in range(1,3):
        
        #linea=tabla.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]/td[3]') 
        
        #boton=linea.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]/td[8]/span/button')

        #tabla_int=driver.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]')
        
    filas=tabla.find_elements(By.TAG_NAME, 'tr')

    data=[]

    for f in filas:

        elementos=f.find_elements(By.TAG_NAME, 'td') 

        tmp=[]

        for e in elementos:

            tmp.append(e.text)
            
            
        data.append(tmp)
    df=pd.DataFrame(data, columns=['index', 'novedad','titulo','pos_Actual','pos_Anterior','semanas_lista', 'streams','unnamed1','unnamed2'])
    
    df['dia']=dia
    
    df.novedad=df.novedad.apply(lambda x: x.split('\n'))
    df.titulo=df.titulo.apply(lambda x: x.split('\n'))
    
    df['posicion1']=None
    df['novedad1']=None
    df['titulo1']=None
    df['autor1']=None
    
    for i in range(len(df.novedad)):
        df['posicion1'][i]=df.novedad[i][0]
        df['novedad1'][i]=df.novedad[i][1]
        df.titulo1[i]=df.titulo[i][0]
        df.autor1[i]=df.titulo[i][1]
        
    df = df.reindex(columns=['index','posicion1','novedad1','titulo1','autor1','pos_Actual','pos_Anterior','semanas_lista',
                             'streams','unnamed1','unnamed2'])
    
    dfs.append(df)
    
    return dfs

# %%
dia='2017-01-01'

conexion('https://charts.spotify.com/charts/view/regional-global-daily/2017-01-01', dia)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\Users\sersu\IRONHACK\Project_Final_Spotify\src\prueba.ipynb Celda 4 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/prueba.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> dia='2017-01-01'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/prueba.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> conexion('https://charts.spotify.com/charts/view/regional-global-daily/2017-01-01', dia)
#
# c:\Users\sersu\IRONHACK\Project_Final_Spotify\src\prueba.ipynb Celda 4 in conexion(url, dia)
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/prueba.ipynb#W2sZmlsZQ%3D%3D?line=26'>27</a> driver.get('https://charts.spotify.com/charts/view/regional-global-daily/2017-01-01')
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/prueba.ipynb#W2sZmlsZQ%3D%3D?line=28'>29</a> time.sleep(2)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/prueba.ipynb#W2sZmlsZQ%3D%3D?line=30'>31</a> tabla=driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody')
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/prueba.ipynb#W2sZmlsZQ%3D%3D?line=33'>34</a> time.sleep(2)
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/prueba.ipynb#W2sZmlsZQ%3D%3D?line=36'>37</a>     #for i in range(1,3):
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/prueba.ipynb#W2sZmlsZQ%3D%3D?line=37'>38</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/prueba.ipynb#W2sZmlsZQ%3D%3D?line=38'>39</a>     #linea=tabla.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]/td[3]')
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/prueba.ipynb#W2sZmlsZQ%3D%3D?line=41'>42</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/prueba.ipynb#W2sZmlsZQ%3D%3D?line=42'>43</a>     #tabla_int=driver.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]')
#
# File c:\Users\sersu\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\sersu\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File c:\Users\sersu\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody"}
#   (Session info: chrome=108.0.5359.98)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x009BF243]
# 	(No symbol) [0x00947FD1]
# 	(No symbol) [0x0083D04D]
# 	(No symbol) [0x0086C0B0]
# 	(No symbol) [0x0086C22B]
# 	(No symbol) [0x0089E612]
# 	(No symbol) [0x008885D4]
# 	(No symbol) [0x0089C9EB]
# 	(No symbol) [0x00888386]
# 	(No symbol) [0x0086163C]
# 	(No symbol) [0x0086269D]
# 	GetHandleVerifier [0x00C59A22+2655074]
# 	GetHandleVerifier [0x00C4CA24+2601828]
# 	GetHandleVerifier [0x00A68C0A+619850]
# 	GetHandleVerifier [0x00A67830+614768]
# 	(No symbol) [0x009505FC]
# 	(No symbol) [0x00955968]
# 	(No symbol) [0x00955A55]
# 	(No symbol) [0x0096051B]
# 	BaseThreadInitThunk [0x76387BA9+25]
# 	RtlInitializeExceptionChain [0x77DCBB9B+107]
# 	RtlClearBits [0x77DCBB1F+191]
