# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

from selenium.webdriver.chrome.options import Options

from selenium.webdriver.support import expected_conditions as EC  # condiciones esperadas...

from selenium.webdriver import ActionChains as AC   # acciones encadenadas, rollo doble click

from selenium.webdriver.common.keys import Keys  # manejar teclas

import time

import pandas as pd

from webdriver_manager.chrome import ChromeDriverManager

PATH=ChromeDriverManager().install()

import warnings
warnings.filterwarnings('ignore')

opciones=Options()

# quita la bandera de ser robot
opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)

opciones.headless=False   # si True, no aparece la ventana (headless=no visible)

opciones.add_argument('--start-maximized')         # comienza maximizado

#opciones.add_extension('driver/adblock.crx')       # adblocker

opciones.add_argument('user-data-dir=selenium')    # mantiene las coockies

# %%
dia='2017-01-01'

# %%
def direccion(url,dia):
    
    
    
    
    driver=webdriver.Chrome(PATH)
    driver.get(url)
    
    time.sleep(2)

    boton_login=driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/main/div[2]/div/header/div/div[2]/a[3]/div[1]').click()
    
    time.sleep(2)
    
    input_mail=driver.find_element(By.XPATH,'//*[@id="login-username"]')
    
    input_mail.send_keys('')  # escribe texto

    input_clave=driver.find_element(By.XPATH,'//*[@id="login-password"]')
    
    
    input_clave.send_keys('')
    
    boton_acceso=driver.find_element(By.XPATH,'//*[@id="login-button"]/div[1]/p').click()
    
    time.sleep(2)
    
    
    driver.get('https://charts.spotify.com/charts/view/regional-global-daily/2017-01-01')
    
    time.sleep(2)
    
    
    tabla=driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody')
    
    
    time.sleep(2)
    

    
    #boton_cookies=driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]').click()
    
    #time.sleep(2)
    
    
    #col=1
    
    #strime=[]
    
    '''for i in range(1,201):
        
        col+=1
        
        streamer=tabla.find_elements(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]/td[7]')
        
        strtr=[]
        for e in streamer:
            strtr.append(e.text)
            
        strime.append(strtr)'''
            
    for i in range(1,3):
        
        linea=tabla.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]/td[3]')
         
         
        
        boton=linea.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]/td[8]/span/button')
        
        
        ''' AC(driver).move_to_element(linea)
        
        AC(driver).click(boton)
        
        AC(driver).perform()'''
        
        
  
        tabla_int=driver.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]')
        
        filas=tabla.find_elements(By.TAG_NAME, 'tr')

        
        data=[]

        for f in filas:

            elementos=f.find_elements(By.TAG_NAME, 'td') 

            tmp=[]

            for e in elementos:

                tmp.append(e.text)
            
            
            data.append(tmp)
    df=pd.DataFrame(data, columns=['index', 'novedad','titulo','pos_Actual','pos_Anterior','semanas_lista', 'streams','unnamed1','unnamed2'])
    
    df['dia']=dia
    
    
    
    
    
    

    return df

# %%
dia='2017-01-01'

holi=direccion('https://charts.spotify.com/charts/view/regional-global-daily/' + dia,dia)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\Users\sersu\IRONHACK\Project_Final_Spotify\src\spoty_dia.ipynb Celda 4 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/spoty_dia.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> dia='2017-01-01'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/spoty_dia.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> holi=direccion('https://charts.spotify.com/charts/view/regional-global-daily/' + dia,dia)
#
# c:\Users\sersu\IRONHACK\Project_Final_Spotify\src\spoty_dia.ipynb Celda 4 in direccion(url, dia)
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/spoty_dia.ipynb#W3sZmlsZQ%3D%3D?line=25'>26</a> time.sleep(2)
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/spoty_dia.ipynb#W3sZmlsZQ%3D%3D?line=32'>33</a> #driver.get('https://charts.spotify.com/charts/view/regional-global-daily/2017-01-01')
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/spoty_dia.ipynb#W3sZmlsZQ%3D%3D?line=33'>34</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/spoty_dia.ipynb#W3sZmlsZQ%3D%3D?line=34'>35</a> #time.sleep(2)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/spoty_dia.ipynb#W3sZmlsZQ%3D%3D?line=41'>42</a> tabla=driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody')
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/spoty_dia.ipynb#W3sZmlsZQ%3D%3D?line=44'>45</a> time.sleep(2)
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/spoty_dia.ipynb#W3sZmlsZQ%3D%3D?line=48'>49</a> #boton_cookies=driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]').click()
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/spoty_dia.ipynb#W3sZmlsZQ%3D%3D?line=49'>50</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/spoty_dia.ipynb#W3sZmlsZQ%3D%3D?line=50'>51</a> #time.sleep(2)
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/spoty_dia.ipynb#W3sZmlsZQ%3D%3D?line=54'>55</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/spoty_dia.ipynb#W3sZmlsZQ%3D%3D?line=55'>56</a> #strime=[]
#
# File c:\Users\sersu\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\sersu\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File c:\Users\sersu\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody"}
#   (Session info: chrome=108.0.5359.98)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x009BF243]
# 	(No symbol) [0x00947FD1]
# 	(No symbol) [0x0083D04D]
# 	(No symbol) [0x0086C0B0]
# 	(No symbol) [0x0086C22B]
# 	(No symbol) [0x0089E612]
# 	(No symbol) [0x008885D4]
# 	(No symbol) [0x0089C9EB]
# 	(No symbol) [0x00888386]
# 	(No symbol) [0x0086163C]
# 	(No symbol) [0x0086269D]
# 	GetHandleVerifier [0x00C59A22+2655074]
# 	GetHandleVerifier [0x00C4CA24+2601828]
# 	GetHandleVerifier [0x00A68C0A+619850]
# 	GetHandleVerifier [0x00A67830+614768]
# 	(No symbol) [0x009505FC]
# 	(No symbol) [0x00955968]
# 	(No symbol) [0x00955A55]
# 	(No symbol) [0x0096051B]
# 	BaseThreadInitThunk [0x76387BA9+25]
# 	RtlInitializeExceptionChain [0x77DCBB9B+107]
# 	RtlClearBits [0x77DCBB1F+191]

# %%
df=pd.DataFrame(holi)

# %%
dfv1=df.copy()

# %%
dfv1.novedad=dfv1.novedad.apply(lambda x: x.split('\n'))
dfv1.titulo=dfv1.titulo.apply(lambda x: x.split('\n'))

# %%
dfv1.novedad[1][0]
dfv1['posicion1']=None
dfv1['novedad1']=None
dfv1['titulo1']=None
dfv1['autor1']=None

# %%
for i in range(len(dfv1.novedad)):
    dfv1['posicion1'][i]=dfv1.novedad[i][0]
    dfv1['novedad1'][i]=dfv1.novedad[i][1]
    dfv1.titulo1[i]=dfv1.titulo[i][0]
    dfv1.autor1[i]=dfv1.titulo[i][1]

# %%
dfv1
# Out:
#     posicion     novedad                                             titulo  \
# 0               [1, NEW]                   [Starboy, The Weeknd, Daft Punk]
# 1               [2, NEW]                 [Closer, The Chainsmokers, Halsey]
# 2               [3, NEW]         [Let Me Love You, DJ Snake, Justin Bieber]
# 3               [4, NEW]  [Rockabye (feat. Sean Paul & Anne-Marie), Clea...
# 4               [5, NEW]                   [One Dance, Drake, Wizkid, Kyla]
# ..       ...         ...                                                ...
# 195           [196, NEW]                       [White Iverson, Post Malone]
# 196           [197, NEW]                               [Oh Lord, MiC LOWRY]
# 197           [198, NEW]     [Superstition - Single Version, Stevie Wonder]
# 198           [199, NEW]                              [Secrets, The Weeknd]
# 199           [200, NEW]               [Ni**as In Paris, JAY-Z, Kanye West]
#
#     pos_Actual pos_Anterior semanas_lista  streamers unnamed1 unnamed2  \
# 0            1            —             1  3,135,625
# 1            2            —             1  3,015,525
# 2            3            —             1  2,545,384
# 3            4            —             1  2,356,604
# 4            5            —             1  2,259,887
# ..         ...          ...           ...        ...      ...      ...
# 195        196            —             1    332,756
# 196        197            —             1    331,792
# 197        198            —             1    331,376
# 198        199            —             1    331,233
# 199        200            —             1    325,951
#
#             dia posicion1 novedad1                                  titulo1  \
# 0    2017-01-01         1      NEW                                  Starboy
# 1    2017-01-01         2      NEW                                   Closer
# 2    2017-01-01         3      NEW                          Let Me Love You
# 3    2017-01-01         4      NEW  Rockabye (feat. Sean Paul & Anne-Marie)
# 4    2017-01-01         5      NEW                                One Dance
# ..          ...       ...      ...                                      ...
# 195  2017-01-01       196      NEW                            White Iverson
# 196  2017-01-01       197      NEW                                  Oh Lord
# 197  2017-01-01       198      NEW            Superstition - Single Version
# 198  2017-01-01       199      NEW                                  Secrets
# 199  2017-01-01       200      NEW                          Ni**as In Paris
#
#                                   autor1
# 0                  The Weeknd, Daft Punk
# 1               The Chainsmokers, Halsey
# 2                DJ Snake, Justin Bieber
# 3    Clean Bandit, Sean Paul, Anne-Marie
# 4                    Drake, Wizkid, Kyla
# ..                                   ...
# 195                          Post Malone
# 196                            MiC LOWRY
# 197                        Stevie Wonder
# 198                           The Weeknd
# 199                    JAY-Z, Kanye West
#
# [200 rows x 14 columns]

# %%
def direccion2(url,dia):
    
    
    
    
    driver=webdriver.Chrome(PATH)
    driver.get(url)
    
    time.sleep(2)

    boton_login=driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/main/div[2]/div/header/div/div[2]/a[3]/div[1]').click()
    
    time.sleep(2)
    
    input_mail=driver.find_element(By.XPATH,'//*[@id="login-username"]')
    
    input_mail.send_keys('superen2000@yahoo.es')  # escribe texto

    input_clave=driver.find_element(By.XPATH,'//*[@id="login-password"]')
    
    
    input_clave.send_keys('Smusica#10y')
    
    boton_acceso=driver.find_element(By.XPATH,'//*[@id="login-button"]/div[1]/p').click()
    
    time.sleep(2)
    
    dias=['2017-01-01','2017-01-02']
    dfs=[]
    
    for i in range(2):
        driver.get('https://charts.spotify.com/charts/view/regional-global-daily/'+dias[i])
        
        time.sleep(2)
        
        
        tabla=driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody')
        
        
        time.sleep(2)
        

        
        #boton_cookies=driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]').click()
        
        #time.sleep(2)
        
        
        #col=1
        
        #strime=[]
        
        '''for i in range(1,201):
            
            col+=1
            
            streamer=tabla.find_elements(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]/td[7]')
            
            strtr=[]
            for e in streamer:
                strtr.append(e.text)
                
            strime.append(strtr)'''
                
        for i in range(1,3):
            
            linea=tabla.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]/td[3]')
            
            
            
            boton=linea.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]/td[8]/span/button')
            
            
            ''' AC(driver).move_to_element(linea)
            
            AC(driver).click(boton)
            
            AC(driver).perform()'''
            
            
    
            tabla_int=driver.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[{i}]')
            
            filas=tabla.find_elements(By.TAG_NAME, 'tr')

            
            data=[]

            for f in filas:

                elementos=f.find_elements(By.TAG_NAME, 'td') 

                tmp=[]

                for e in elementos:

                    tmp.append(e.text)
                
                
                data.append(tmp)
        df=pd.DataFrame(data, columns=['index', 'novedad','titulo','pos_Actual','pos_Anterior','semanas_lista', 'streams','unnamed1','unnamed2'])
        
        df['dia']=dias[i]
        
        df.novedad=df.novedad.apply(lambda x: x.split('\n'))
        df.titulo=df.titulo.apply(lambda x: x.split('\n'))
        
        df['posicion1']=None
        df['novedad1']=None
        df['titulo1']=None
        df['autor1']=None
        
        for i in range(len(df.novedad)):
            df['posicion1'][i]=df.novedad[i][0]
            df['novedad1'][i]=df.novedad[i][1]
            df.titulo1[i]=df.titulo[i][0]
            df.autor1[i]=df.titulo[i][1]
            
        df = df.reindex(columns=['index','dia','posicion1','novedad1','titulo1','autor1','pos_Actual','pos_Anterior','semanas_lista',
                                'streams','unnamed1','unnamed2'])
        dfs.append(df)

    return dfs

# %%
dia='2017-01-01'

holi=direccion2('https://charts.spotify.com/charts/view/regional-global-daily/' + dia,dia)

# %%
holi[1]
# Out:
#     index         dia posicion1 novedad1  \
# 0          2017-01-01         1       –
# 1          2017-01-01         2       –
# 2          2017-01-01         3        1
# 3          2017-01-01         4        1
# 4          2017-01-01         5        3
# ..    ...         ...       ...      ...
# 195        2017-01-01       196      NEW
# 196        2017-01-01       197      NEW
# 197        2017-01-01       198      NEW
# 198        2017-01-01       199      NEW
# 199        2017-01-01       200      NEW
#
#                                      titulo1  \
# 0                                    Starboy
# 1                                     Closer
# 2    Rockabye (feat. Sean Paul & Anne-Marie)
# 3                            Let Me Love You
# 4    Don't Wanna Know (feat. Kendrick Lamar)
# ..                                       ...
# 195                                    Sugar
# 196                    Kill Em With Kindness
# 197                           Mr. Brightside
# 198                                    Don't
# 199                        Take Me To Church
#
#                                   autor1 pos_Actual pos_Anterior  \
# 0                  The Weeknd, Daft Punk          1            1
# 1               The Chainsmokers, Halsey          2            2
# 2    Clean Bandit, Sean Paul, Anne-Marie          3            4
# 3                DJ Snake, Justin Bieber          3            3
# 4               Maroon 5, Kendrick Lamar          5            8
# ..                                   ...        ...          ...
# 195                             Maroon 5        196            —
# 196                         Selena Gomez        197            —
# 197                          The Killers        198            —
# 198                        Bryson Tiller        199            —
# 199                               Hozier        200            —
#
#     semanas_lista    streams unnamed1 unnamed2
# 0               2  3,342,769
# 1               2  3,019,058
# 2               2  2,726,981
# 3               2  2,524,666
# 4               2  2,362,830
# ..            ...        ...      ...      ...
# 195             1    335,115
# 196             1    333,694
# 197             1    333,579
# 198             1    331,803
# 199             1    330,936
#
# [200 rows x 12 columns]
