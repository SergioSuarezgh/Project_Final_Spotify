# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

from selenium.webdriver.chrome.options import Options

from selenium.webdriver.support import expected_conditions as EC  # condiciones esperadas...

from selenium.webdriver import ActionChains as AC   # acciones encadenadas, rollo doble click

from selenium.webdriver.common.keys import Keys  # manejar teclas

import time

import pandas as pd
pd.set_option('display.max_columns', None)   
pd.set_option('display.max_rows', None)

from webdriver_manager.chrome import ChromeDriverManager

PATH=ChromeDriverManager().install()

import warnings
warnings.filterwarnings('ignore')

opciones=Options()

# quita la bandera de ser robot
opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)

opciones.headless=False   # si True, no aparece la ventana (headless=no visible)

opciones.add_argument('--start-maximized')         # comienza maximizado

#opciones.add_extension('driver/adblock.crx')       # adblocker

opciones.add_argument('user-data-dir=selenium')    # mantiene las coockies

import Utils
from datetime import date

from decouple import config
user_spoty = config('user_spoty', default='')
pass_spoty = config('pass_spoty', default='')

from joblib import Parallel, delayed

# %%
fechas=['2021-10-21','2021-10-28','2021-11-04','2021-11-11','2021-11-18','2021-11-25','2021-12-02','2021-12-09',
        '2021-12-16','2021-12-23','2021-12-30','2022-01-06','2022-01-13','2022-01-20','2022-01-27','2022-02-03',
        '2022-02-10','2022-02-17','2022-02-24','2022-03-03','2022-03-10','2022-03-17','2022-03-24','2022-03-31',
        '2022-04-07','2022-04-14','2022-04-21','2022-04-28','2022-05-05','2022-05-12','2022-05-19','2022-05-26',
        '2022-06-02','2022-06-09','2022-06-16','2022-06-23','2022-06-30','2022-07-07','2022-07-14','2022-07-21',
        '2022-07-28','2022-08-04','2022-08-11','2022-08-18','2022-08-25','2022-09-01','2022-09-08','2022-09-15',
        '2022-09-22','2022-09-29','2022-10-06','2022-10-13','2022-10-20','2022-10-27','2022-11-03','2022-11-10',
        '2022-11-17','2022-11-24','2022-12-01','2022-12-08']

ciudades=['madrid','barcelona','bilbao','malaga','seville','valencia']

# %%
def direccion(url,semana,ciudad):

    
    
    
    driver.get(f'https://charts.spotify.com/charts/view/citytoptrack-{ciudad}-weekly/{semana}')
    
    
    
    time.sleep(2)
    
    
    tabla=driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody')
    
    
    time.sleep(2)
    
        
    '''
    linea=tabla.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[1]').click()
         
 
    time.sleep(2)
  
    tabla_int=driver.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[2]/td[3]/table/tbody')'''
                                            
    filas=tabla.find_elements(By.TAG_NAME, 'tr')

        
    data=[]

    for f in filas:

        elementos=f.find_elements(By.TAG_NAME, 'td') 

        tmp=[]

        for e in elementos:

            tmp.append(e.text)
            
            
        data.append(tmp)
    df=pd.DataFrame(data)
    
    df.rename(columns={1:'position',2:'autor_cancion',3:'peak_rank',4:'previous_rank',5: 'days_on_chart'},inplace=True)
    df.position=df.position.apply(lambda x: x.split('\n')[0])
    df['artist_names']=df.autor_cancion
    df['track_name']=df.autor_cancion
    df['fecha']=semana

    df.autor_cancion=df.autor_cancion.apply(lambda x: x.split('\n'))

    for i in range(len(df)):
        df['artist_names'][i]=df.autor_cancion[i][1]
        df['track_name'][i]=df.autor_cancion[i][0]
    
    df.drop(columns='autor_cancion', inplace=True)

    df=df.reindex(columns=[ 'fecha','artist_names','track_name','position','previous_rank','peak_rank','days_on_chart'])


    
    


    return df

# %%
driver=webdriver.Chrome(PATH)
driver.get('https://charts.spotify.com/charts/view/citytoptrack-valencia-weekly/2022-12-08')
    
time.sleep(2)

boton_login=driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/main/div[2]/div/header/div/div[2]/a[3]/div[1]').click()
    
time.sleep(2)
    
input_mail=driver.find_element(By.XPATH,'//*[@id="login-username"]')
    
input_mail.send_keys(user_spoty)  # escribe texto

input_clave=driver.find_element(By.XPATH,'//*[@id="login-password"]')
    
    
input_clave.send_keys(pass_spoty)
    
boton_acceso=driver.find_element(By.XPATH,'//*[@id="login-button"]/div[1]/p').click()

time.sleep(10)
    
cookies=driver.find_element(By.XPATH,'//*[@id="onetrust-accept-btn-handler"]').click()
    
time.sleep(2)
for i in fechas[:2]:
    df=direccion('https://charts.spotify.com/charts/view/citytoptrack-valencia-weekly/2022-12-08',i,'valencia')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\Users\sersu\IRONHACK\Project_Final_Spotify\src\ciudades.ipynb Celda 4 in <cell line: 26>()
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/ciudades.ipynb#W3sZmlsZQ%3D%3D?line=24'>25</a> time.sleep(2)
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/ciudades.ipynb#W3sZmlsZQ%3D%3D?line=25'>26</a> for i in fechas[:2]:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/ciudades.ipynb#W3sZmlsZQ%3D%3D?line=26'>27</a>     df=direccion('https://charts.spotify.com/charts/view/citytoptrack-valencia-weekly/2022-12-08',i,'valencia')
#
# c:\Users\sersu\IRONHACK\Project_Final_Spotify\src\ciudades.ipynb Celda 4 in direccion(url, semana, ciudad)
#       <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/ciudades.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> driver.get(f'https://charts.spotify.com/charts/view/citytoptrack-{ciudad}-weekly/{semana}')
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/ciudades.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> time.sleep(2)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/ciudades.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a> tabla=driver.find_element(By.XPATH,'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody')
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/ciudades.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a> time.sleep(2)
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/ciudades.ipynb#W3sZmlsZQ%3D%3D?line=18'>19</a> '''
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/ciudades.ipynb#W3sZmlsZQ%3D%3D?line=19'>20</a> linea=tabla.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[1]').click()
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/ciudades.ipynb#W3sZmlsZQ%3D%3D?line=20'>21</a>
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/ciudades.ipynb#W3sZmlsZQ%3D%3D?line=23'>24</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/sersu/IRONHACK/Project_Final_Spotify/src/ciudades.ipynb#W3sZmlsZQ%3D%3D?line=24'>25</a> tabla_int=driver.find_element(By.XPATH,f'//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody/tr[2]/td[3]/table/tbody')'''
#
# File c:\Users\sersu\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\sersu\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File c:\Users\sersu\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="__next"]/div/div/main/div[2]/div[3]/div/table/tbody"}
#   (Session info: chrome=108.0.5359.99)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x005CF243]
# 	(No symbol) [0x00557FD1]
# 	(No symbol) [0x0044D04D]
# 	(No symbol) [0x0047C0B0]
# 	(No symbol) [0x0047C22B]
# 	(No symbol) [0x004AE612]
# 	(No symbol) [0x004985D4]
# 	(No symbol) [0x004AC9EB]
# 	(No symbol) [0x00498386]
# 	(No symbol) [0x0047163C]
# 	(No symbol) [0x0047269D]
# 	GetHandleVerifier [0x00869A22+2655074]
# 	GetHandleVerifier [0x0085CA24+2601828]
# 	GetHandleVerifier [0x00678C0A+619850]
# 	GetHandleVerifier [0x00677830+614768]
# 	(No symbol) [0x005605FC]
# 	(No symbol) [0x00565968]
# 	(No symbol) [0x00565A55]
# 	(No symbol) [0x0057051B]
# 	BaseThreadInitThunk [0x76287BA9+25]
# 	RtlInitializeExceptionChain [0x7716BB9B+107]
# 	RtlClearBits [0x7716BB1F+191]

# %%
df.head()
# Out:
#         fecha         artist_names                             track_name  \
# 0  2022-12-08  Arcángel, Bad Bunny                               La Jumpa
# 1  2022-12-08              Quevedo                                Punto G
# 2  2022-12-08        Manuel Turizo                             La Bachata
# 3  2022-12-08    Bizarrap, Quevedo  Quevedo: Bzrp Music Sessions, Vol. 52
# 4  2022-12-08          Ozuna, Feid                                Hey Mor
#
#   position previous_rank peak_rank days_on_chart
# 0        1             —         1             1
# 1        2             1         1             5
# 2        3             2         1            26
# 3        4             4         1            23
# 4        5             3         2             9

# %%
df2=df.copy()

# %%
df.head()

# %%
df2.rename(columns={1:'position',2:'autor_cancion',3:'peak_rank',4:'previous_rank',5: 'days_on_chart'},inplace=True)
df2.position=df2.position.apply(lambda x: x.split('\n')[0])
df2['artist_names']=df2.autor_cancion
df2['track_name']=df2.autor_cancion

df2.autor_cancion=df2.autor_cancion.apply(lambda x: x.split('\n'))

for i in range(len(df2)):
    df2['artist_names'][i]=df2.autor_cancion[i][1]
    df2['track_name'][i]=df2.autor_cancion[i][0]
    
df2.drop(columns='autor_cancion', inplace=True)

df2=df2.reindex(columns=[ 'artist_names','track_name','position','previous_rank','peak_rank','days_on_chart'])

df2.head()
# Out:
#           artist_names                             track_name position  \
# 0  Arcángel, Bad Bunny                               La Jumpa        1
# 1              Quevedo                                Punto G        2
# 2        Manuel Turizo                             La Bachata        3
# 3    Bizarrap, Quevedo  Quevedo: Bzrp Music Sessions, Vol. 52        4
# 4          Ozuna, Feid                                Hey Mor        5
#
#   previous_rank peak_rank days_on_chart
# 0             —         1             1
# 1             1         1             5
# 2             2         1            26
# 3             4         1            23
# 4             3         2             9

# %%
df2.pos
